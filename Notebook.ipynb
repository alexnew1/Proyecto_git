# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('datasets/Data_Set_2023.xlsx')
df.head()
# Out:
#    OBJECTID event_id_cnty event_date  year time_precision  \
# 0   1757812        BLZ975 2023-07-23  2023    actual date
# 1   1859269        BLZ996 2023-11-22  2023    actual date
# 2   1610505        BLZ414 2023-01-04  2023    actual date
# 3   1667625        BLZ423 2023-03-19  2023    actual date
# 4   1699647        BLZ945 2023-04-28  2023    actual date
#
#                    event_type                             actor1  \
# 0  Violence against civilians         Unidentified Gang (Belize)
# 1                    Protests                Protesters (Belize)
# 2  Violence against civilians         Unidentified Gang (Belize)
# 3  Violence against civilians  Unidentified Armed Group (Belize)
# 4                     Battles  Unidentified Armed Group (Belize)
#
#                                         ally_actor_1             inter1  \
# 0                                                NaN  Political militia
# 1  Government of Belize (2020-); Former Governmen...        Protesters
# ...

# %%
df.columns
# Out:
# Index(['OBJECTID', 'event_id_cnty', 'event_date', 'year', 'time_precision',
#        'event_type', 'actor1', 'ally_actor_1', 'inter1', 'actor2',
#        'ally_actor_2', 'inter2', 'interaction', 'country', 'admin1', 'admin2',
#        'admin3', 'location', 'geo_precision', 'source', 'notes',
#        'FMETimeStamp', 'Country_ISO2', 'Admin01Code', 'Admin01Name',
#        'longitude', 'latitude', 'region', 'source_scale', 'sub_event_type',
#        'timestamp', 'civilian_actor2', 'civilians_interaction',
#        'civilian_casualties_1', 'civilian_casualties_2',
#        'civilian_casualties_3', 'prot_class_1', 'prot_class_2', 'prot_class_3',
#        'prot_class_4', 'prot_class_5', 'prot_class_6', 'prot_class_7',
#        'prot_class_8', 'prot_class_9', 'civilian_actor1', 'event_category',
#        'last_updated', 'ACLED_UpdateStatus', 'fatalities', 'inter1_code',
#        'inter2_code', 'interaction_code', 'civilian_targeting',
#        'disorder_type', 'tags'],
# ...

# %%
df.shape
# Out:
# (7501, 56)

# %%
df.describe()
# Out:
#            OBJECTID                     event_date    year  \
# count  7.501000e+03                           7501  7501.0
# mean   1.761190e+06  2023-07-08 13:29:21.845087488  2023.0
# min    1.608756e+06            2023-01-01 00:00:00  2023.0
# 25%    1.694694e+06            2023-04-17 00:00:00  2023.0
# 50%    1.756044e+06            2023-07-06 00:00:00  2023.0
# 75%    1.827385e+06            2023-10-06 00:00:00  2023.0
# max    1.972342e+06            2023-12-31 00:00:00  2023.0
# std    8.692533e+04                            NaN     0.0
#
#                         FMETimeStamp    longitude     latitude     timestamp  \
# count                           7501  7501.000000  7501.000000  7.501000e+03
# mean   2023-08-28 10:48:52.409012224   -93.547305    17.042574  1.692770e+09
# min              2023-01-17 00:00:00  -107.784400     7.406800  1.673896e+09
# 25%              2023-05-23 00:00:00   -98.673300    14.630600  1.684790e+09
# ...

# %% [markdown]
# # Aquí se va agregar un modelo 1
